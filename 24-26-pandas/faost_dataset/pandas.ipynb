# %% [markdown]
# # Assignment
# ## Data of climate change

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('FAOSTAT_data_1-17-2022.csv')
df
# Out:
#    Domain Code              Domain  Area Code (FAO)         Area  \
# 0           ET  Temperature change                2  Afghanistan
# 1           ET  Temperature change                2  Afghanistan
# 2           ET  Temperature change                2  Afghanistan
# 3           ET  Temperature change               16   Bangladesh
# 4           ET  Temperature change               16   Bangladesh
# 5           ET  Temperature change               16   Bangladesh
# 6           ET  Temperature change              100        India
# 7           ET  Temperature change              100        India
# 8           ET  Temperature change              100        India
# 9           ET  Temperature change              165     Pakistan
# 10          ET  Temperature change              165     Pakistan
# 11          ET  Temperature change              165     Pakistan
#
#     Element Code             Element  Months Code    Months  Year Code  Year  \
# ...

# %%
df.head(5)
# Out:
#   Domain Code              Domain  Area Code (FAO)         Area  Element Code  \
# 0          ET  Temperature change                2  Afghanistan          7271
# 1          ET  Temperature change                2  Afghanistan          7271
# 2          ET  Temperature change                2  Afghanistan          7271
# 3          ET  Temperature change               16   Bangladesh          7271
# 4          ET  Temperature change               16   Bangladesh          7271
#
#               Element  Months Code    Months  Year Code  Year Unit  Value  \
# 0  Temperature change         7010   October       2020  2020   ?C -1.042
# 1  Temperature change         7011  November       2020  2020   ?C -0.503
# 2  Temperature change         7012  December       2020  2020   ?C -1.792
# 3  Temperature change         7010   October       2020  2020   ?C  2.469
# 4  Temperature change         7011  November       2020  2020   ?C  1.688
#
#   Flag Flag Description
# 0   Fc  Calculated data
# ...

# %%
df.tail(6)
# Out:
#    Domain Code              Domain  Area Code (FAO)      Area  Element Code  \
# 6           ET  Temperature change              100     India          7271
# 7           ET  Temperature change              100     India          7271
# 8           ET  Temperature change              100     India          7271
# 9           ET  Temperature change              165  Pakistan          7271
# 10          ET  Temperature change              165  Pakistan          7271
# 11          ET  Temperature change              165  Pakistan          7271
#
#                Element  Months Code    Months  Year Code  Year Unit  Value  \
# 6   Temperature change         7010   October       2020  2020   ?C  1.274
# 7   Temperature change         7011  November       2020  2020   ?C  0.703
# 8   Temperature change         7012  December       2020  2020   ?C  0.825
# 9   Temperature change         7010   October       2020  2020   ?C -0.172
# ...

# %%
df.mean()
# Out:
# C:\Users\HEWLET~1\AppData\Local\Temp/ipykernel_3980/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Area Code (FAO)      70.75000
# Element Code       7271.00000
# Months Code        7011.00000
# Year Code          2020.00000
# Year               2020.00000
# Value                 0.30325
# dtype: float64

# %%
df.groupby(['Area','Value']).mean()
# Out:
#                     Area Code (FAO)  Element Code  Months Code  Year Code  \
# Area        Value
# Afghanistan -1.792              2.0        7271.0       7012.0     2020.0
#             -1.042              2.0        7271.0       7010.0     2020.0
#             -0.503              2.0        7271.0       7011.0     2020.0
# Bangladesh   0.872             16.0        7271.0       7012.0     2020.0
#              1.688             16.0        7271.0       7011.0     2020.0
#              2.469             16.0        7271.0       7010.0     2020.0
# India        0.703            100.0        7271.0       7011.0     2020.0
#              0.825            100.0        7271.0       7012.0     2020.0
#              1.274            100.0        7271.0       7010.0     2020.0
# Pakistan    -0.419            165.0        7271.0       7011.0     2020.0
#             -0.264            165.0        7271.0       7012.0     2020.0
# ...

# %%
df.to_excel('df.xlsx')

# %%
df.drop(['Element Code','Year Code','Domain Code','Months Code','Flag Description'],axis=1)
# Out:
#                 Domain  Area Code (FAO)         Area             Element  \
# 0   Temperature change                2  Afghanistan  Temperature change
# 1   Temperature change                2  Afghanistan  Temperature change
# 2   Temperature change                2  Afghanistan  Temperature change
# 3   Temperature change               16   Bangladesh  Temperature change
# 4   Temperature change               16   Bangladesh  Temperature change
# 5   Temperature change               16   Bangladesh  Temperature change
# 6   Temperature change              100        India  Temperature change
# 7   Temperature change              100        India  Temperature change
# 8   Temperature change              100        India  Temperature change
# 9   Temperature change              165     Pakistan  Temperature change
# 10  Temperature change              165     Pakistan  Temperature change
# 11  Temperature change              165     Pakistan  Temperature change
#
# ...

# %%
df2=df.head(5)
df2
# Out:
#   Domain Code              Domain  Area Code (FAO)         Area  Element Code  \
# 0          ET  Temperature change                2  Afghanistan          7271
# 1          ET  Temperature change                2  Afghanistan          7271
# 2          ET  Temperature change                2  Afghanistan          7271
# 3          ET  Temperature change               16   Bangladesh          7271
# 4          ET  Temperature change               16   Bangladesh          7271
#
#               Element  Months Code    Months  Year Code  Year Unit  Value  \
# 0  Temperature change         7010   October       2020  2020   ?C -1.042
# 1  Temperature change         7011  November       2020  2020   ?C -0.503
# 2  Temperature change         7012  December       2020  2020   ?C -1.792
# 3  Temperature change         7010   October       2020  2020   ?C  2.469
# 4  Temperature change         7011  November       2020  2020   ?C  1.688
#
#   Flag Flag Description
# 0   Fc  Calculated data
# ...

# %%
df.groupby(['Domain','Area','Value']).mean()
# Out:
#                                        Area Code (FAO)  Element Code  \
# Domain             Area        Value
# Temperature change Afghanistan -1.792              2.0        7271.0
#                                -1.042              2.0        7271.0
#                                -0.503              2.0        7271.0
#                    Bangladesh   0.872             16.0        7271.0
#                                 1.688             16.0        7271.0
#                                 2.469             16.0        7271.0
#                    India        0.703            100.0        7271.0
#                                 0.825            100.0        7271.0
#                                 1.274            100.0        7271.0
#                    Pakistan    -0.419            165.0        7271.0
#                                -0.264            165.0        7271.0
#                                -0.172            165.0        7271.0
#
# ...
