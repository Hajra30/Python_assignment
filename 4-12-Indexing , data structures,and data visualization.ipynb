# %% [markdown]
# # session day 4
# # -Indexing

# %% [markdown]
# ## make a string

# %%
a="samosa,pakora"
a
# Out:
# 'samosa,pakora'

# %% [markdown]
# ### length of indeces

# %%
len(a)
# Out:
# 13

# %%
a[5]
# Out:
# 'a'

# %%
a[0:7]
# Out:
# 'samosa,'

# %%
#last index is exclusive
#nubering always start from 0

# %%
a[-6:-1]
# Out:
# 'pakor'

# %%
#for going backward length should be known

# %% [markdown]
# ### String Methods

# %%
food="biryani"
food
# Out:
# 'biryani'

# %%
len(food)
# Out:
# 7

# %%
food.capitalize()
# Out:
# 'Biryani'

# %%
food.upper()
# Out:
# 'BIRYANI'

# %%
food.casefold()
# Out:
# 'biryani'

# %% [markdown]
# #replacing one with other

# %%
food.replace("b" , "sh")
# Out:
# 'shiryani'

# %% [markdown]
# #counting

# %%
food.count("a")
# Out:
# 1

# %% [markdown]
# ### finding index number in string

# %%
name="Hajra Anwar"
name
# Out:
# 'Hajra Anwar'

# %%
name.find("n")
# Out:
# 7

# %% [markdown]
# #how to split a string

# %%
food= "i love briyani,samosa,pasta,raita"
food
# Out:
# 'i love briyani,samosa,pasta,raita'

# %%
food.rsplit(",")
# Out:
# ['i love briyani', 'samosa', 'pasta', 'raita']

# %% [markdown]
# # session day 5
# # BASIC DATA STRUCTURES IN PYTHON

# %% [markdown]
# 1-Tuple
# 2-List
# 3-Dictionaries
# 4-Set

# %% [markdown]
# ## 1-Tuple
# 1-ordered collection of data
# 2-inclosed in ()
# 3-different kind of elements can be stored
# 4-once elements arte stored you cannot change them

# %% [markdown]
# ### example

# %%
tup1=(1,"python", 2.5)
tup1
# Out:
# (1, 'python', 2.5)

# %% [markdown]
# ### type of tuple

# %%
type(tup1)
# Out:
# tuple

# %% [markdown]
# ### indexing in tuple

# %%
tup1[2]
# Out:
# 2.5

# %%
tup1[0]
# Out:
# 1

# %%
tup1[0:1]
# Out:
# (1,)

# %% [markdown]
# ### count of elements in tuple

# %%
len(tup1)
# Out:
# 3

# %% [markdown]
# ### adding two tuples (concatinate)

# %%
tup2=(2,"hey", 4.5)
tup2
# Out:
# (2, 'hey', 4.5)

# %%
tup1+tup2
# Out:
# (1, 'python', 2.5, 2, 'hey', 4.5)

# %%
tup1*2+tup2
# Out:
# (1, 'python', 2.5, 1, 'python', 2.5, 2, 'hey', 4.5)

# %% [markdown]
# ## 2-list
#
# .ordered collection of elements
# .enclosed in []
# .mutateable

# %%
list1=[2, "me", "false"]
list1
# Out:
# [2, 'me', 'false']

# %% [markdown]
# ### length of list

# %%
len(list1)
# Out:
# 3

# %%
list1[2]
# Out:
# 'false'

# %%
list2=[3,5,"Ammar","codanics",3.4,"false"]
list2
# Out:
# [3, 5, 'Ammar', 'codanics', 3.4, 'false']

# %%
list1.reverse()
list1
# Out:
# ['false', 'me', 2]

# %%
list1*2
# Out:
# ['false', 'me', 2, 'false', 'me', 2]

# %%
list1+list2
# Out:
# ['false', 'me', 2, 3, 5, 'Ammar', 'codanics', 3.4, 'false']

# %%
type(list1)
# Out:
# list

# %% [markdown]
# ### sorting

# %%
#e.g

# %%
list3=[20,11,13,14,21,56,67,70]
list3
# Out:
# [20, 11, 13, 14, 21, 56, 67, 70]

# %%
list3*3
# Out:
# [20,
#  11,
#  13,
#  14,
#  21,
#  56,
#  67,
#  70,
#  20,
#  11,
#  13,
#  14,
#  21,
#  56,
#  67,
#  70,
#  20,
#  11,
#  13,
#  14,
#  21,
#  56,
#  67,
#  70]

# %%
#concatinate
list1+list2+list3
# Out:
# ['false',
#  'me',
#  2,
#  3,
#  5,
#  'Ammar',
#  'codanics',
#  3.4,
#  'false',
#  20,
#  11,
#  13,
#  14,
#  21,
#  56,
#  67,
#  70]

# %% [markdown]
# ## 3- Dictionaries
# .An unordered collection of eliments
# .key and values
# .curly brackets
# .mutateble

# %%
#food and their prices
d1={"samosa":20, "roll":10, "raita":50}
d1
# Out:
# {'samosa': 20, 'roll': 10, 'raita': 50}

# %%
type(d1)
# Out:
# dict

# %% [markdown]
# ### extract data

# %%
keys1=d1.keys()
keys1
# Out:
# dict_keys(['samosa', 'roll', 'raita'])

# %%
values=d1.values()
values
# Out:
# dict_values([20, 10, 50])

# %% [markdown]
# ### adding new element

# %%
d1["tikki"]=15
d1
# Out:
# {'samosa': 20, 'roll': 10, 'raita': 50, 'tikki': 15}

# %%
d2={"dates":300, "choclates":200, "sawaiyan":1000}
d2
# Out:
# {'dates': 300, 'choclates': 200, 'sawaiyan': 1000}

# %%
#concatinate
d1.update(d2)
d1
# Out:
# {'samosa': 20,
#  'roll': 10,
#  'raita': 50,
#  'tikki': 15,
#  'dates': 300,
#  'choclates': 200,
#  'sawaiyan': 1000}

# %% [markdown]
# ## 4- sets
# .unordered
# .no duplicates allowed
# .no concept of keys and values
# .curly braces

# %%
s1={1,2,4,5,"ammar", "atd", "true"}
s1
# Out:
# {1, 2, 4, 5, 'ammar', 'atd', 'true'}

# %%
s1.add("amna")
s1
# Out:
# {1, 2, 4, 5, 'ammar', 'amna', 'atd', 'true'}

# %%
s1.remove("ammar")
s1
# Out:
# {1, 2, 4, 5, 'amna', 'atd', 'true'}

# %% [markdown]
# # SESSION DAY 6

# %% [markdown]
# ## BMI PROGRAM

# %%
height=input("what is your height?")
height
# Out:
# what is your height?1.72
# '1.72'

# %%
height=float(height)

# %%
weight=input("what is your weight?")
weight
# Out:
# what is your weight?47
# '47'

# %%
weight=float(weight)

# %%
name=input("what is your name?")
name
# Out:
# what is your name?hajra
# 'hajra'

# %%
BMI=weight/height**2
BMI
# Out:
# 15.886965927528395

# %%
print("My name is",name,"and my BMI is",BMI )
# Out:
# My name is hajra and my BMI is 15.886965927528395

# %% [markdown]
# # session day 8
# # DATA VISSUALIZATION

# %% [markdown]
# ## BAR PLOTS

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="ticks",color_codes=True)

# %%
titanic=sns.load_dataset("titanic")

# %%
sns.catplot(x="sex",y="survived",hue="class",kind="bar",data=titanic)

# %% [markdown]
# ## COUNTPLOTS

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="ticks",color_codes=True)

# %%
titanic=sns.load_dataset("titanic")

# %%
p1=sns.countplot(x="sex",data=titanic,hue='class')

# %% [markdown]
# ## SCATTER PLOTS

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="ticks",color_codes=True)

# %%
titanic=sns.load_dataset("titanic")

# %%
g=sns.FacetGrid(titanic,row="sex",hue="alone")

# %%
g=(g.map(plt.scatter,"age","fare").add_legend())

# %% [markdown]
# # LINE AND BAR  PLOTS IN PYTHON

# %% [markdown]
# # line plot

# %%
# import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
iris=sns.load_dataset("iris")
iris

# draw a linee plot
sns.lineplot(x="sepal_length",y="sepal_width",data=iris)
plt.show()

# %% [markdown]
# ## adding titles

# %%
# import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
iris=sns.load_dataset("iris")
iris

# draw a linee plot
sns.lineplot(x="sepal_length",y="sepal_width",data=iris)
plt.title("iris_plot")
plt.show()

# %% [markdown]
# ## Adding limits

# %%
# import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
iris=sns.load_dataset("iris")
iris

# draw a linee plot
sns.lineplot(x="sepal_length",y="sepal_width",data=iris)
plt.title("iris_plot")
plt.xlim(2)
plt.show()

# %%
# import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
iris=sns.load_dataset("iris")
iris

# draw a linee plot
sns.lineplot(x="sepal_length",y="sepal_width",data=iris)
plt.title("iris_plot")
plt.ylim(1)
plt.show()

# %% [markdown]
# ## Set styles
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %%
# use code:sns.set_theme
 #          sns.set_style(style=None,rc=None)

# %%
# import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
iris=sns.load_dataset("iris")
iris

# draw a linee plot
sns.lineplot(x="sepal_length",y="sepal_width",data=iris)
plt.title("iris_plot")
sns.set_theme
sns.set_style(style=None,rc=None)
sns.set_style("darkgrid")
plt.show()

# %% [markdown]
# ## Size of figure

# %%
# import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
iris=sns.load_dataset("iris")
iris
# change figure
plt.figure(figsize=(4,2))

# draw a linee plot
sns.lineplot(x="sepal_length",y="sepal_width",data=iris)
plt.title("iris_plot")
plt.show()

# %% [markdown]
# # Bar plot

# %%
# import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
iris=sns.load_dataset("iris")
iris

# draw a bar plot
sns.barplot(x="species",y="sepal_width",data=iris)
plt.title("iris_plot")
plt.show()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
iris=sns.load_dataset("iris")
iris
plt.figure(figsize=(7,8))

# draw a bar plot
sns.barplot(x="sepal_length",y="petal_width",data=iris)
plt.title("iris_plot")
plt.show()

# %%
# import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
titanic=sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
titanic=sns.load_dataset("titanic")
titanic
plt.figure(figsize=(13,6))
# draw a linee plot
sns.barplot(x="age",y="survived",data=titanic)
plt.title("titanic_plot")
plt.show()

# %%
# import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
titanic=sns.load_dataset("titanic")
titanic

# draw a linee plot
sns.barplot(x="who",y="alone",hue="sex",data=titanic)
plt.title("titanic_plot")
plt.show()

# %% [markdown]
# ## changing order and changing color

# %%
#import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
titanic=sns.load_dataset("titanic")
titanic

# draw a linee plot
sns.barplot(x="sex",y="alone",hue="who",data=titanic,order=["female","male"],color="blue")
plt.title("titanic_plot")
plt.show()

# %% [markdown]
# ## For mean and Median (import numpy )

# %%
#import libraries 
import seaborn as sns
from numpy import mean
import matplotlib.pyplot as plt

# load dataset
titanic=sns.load_dataset("titanic")
titanic

# draw a linee plot
sns.barplot(y="who",x="alone",hue="sex",data=titanic,color="red",estimator=mean,saturation=1)
plt.title("titanic_plot")
plt.show()

# %%
#importing the required library
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
titanic=sns.load_dataset("titanic")
titanic

# draw a linee plot
sns.barplot(x="class",y="fare",data=titanic,linewidth=7)
plt.title("titanic_plot")
plt.show()

# %% [markdown]
# # session day 10
# # Box plot

# %%
# import libraries 
import seaborn 
#canvas (baloon board)
seaborn.set(style='whitegrid')


# load dataset
titanic = seaborn.load_dataset("titanic")

# draw a box plot
seaborn.boxplot(x="class",y="fare",data=titanic)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
import seaborn 
seaborn.set(style='whitegrid')
tip=seaborn.load_dataset('tips')
tip

# draw a box plot
seaborn.boxplot(x='day',y='tip',data=tip,saturation=2)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import pandas as pf
import numpy as np
seaborn.set(style='whitegrid')
tip=seaborn.load_dataset('tips')
seaborn.boxplot(y='day',x='tip',data=tip,saturation=2)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %% [markdown]
# # session day 11
# # CUSTOMIZNG PLOTS IN PYTHON

# %%
import seaborn as sns 
import pandas as pd
import numpy as np
titanic =sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import seaborn as sns 
import pandas as pd
import numpy as np
titanic=sns.load_dataset("titanic")
sns.boxplot(x="who",y="age",data=titanic)
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
import seaborn as sns 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
titanic=sns.load_dataset("titanic")
sns.boxplot(x="who",y="age",showmeans=True,data=titanic,)
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
sns.boxplot(x="who",y="age",showmeans=True,meanprops={"marker":"*","markersize":"12","markeredgecolor":"yellow"},data=titanic)
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %% [markdown]
# # session day 12
# ## OTHER PLOTS

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dot=sns.load_dataset("dots")
dot.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
titanic=sns.load_dataset("titanic")
                         
#defining a color pelette
p=sns.color_palette('rocket_r') 

#plot lineplot
sns.relplot(data=dot,x="time",y="firing_rate",hue="coherence",size="choice",col="align",kind="line",size_order=["T1","T2"],palette=p,height=5,aspect=.75,facet_kws=dict(sharex=False),)

# %%
import seaborn as sns 
sns.set_theme(style ="ticks")
df=sns.load_dataset("penguins")
sns.pairplot(df,hue="species")

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

# Simulate data from a bivariate Gaussian
n = 10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

# Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)
# Out:
# <AxesSubplot:>
